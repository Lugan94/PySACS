# %%
from time import perf_counter
from functools import wraps

def medir_tiempo(func):
    @wraps(func)
    def wrapper(*args, **kwargs):
        inicio = perf_counter()
        resultado = func(*args, **kwargs)
        fin = perf_counter()
        print(f"Función '{func.__name__}' tardó: {fin - inicio:.6f} s")
        return resultado
    return wrapper

import numpy as np

@medir_tiempo
def crear_lista_python(n):
    return [i for i in range(n)]

@medir_tiempo
def crear_array_numpy(n):
    return np.arange(n)

# Prueba con 10 millones de elementos
n = 10_000_000
crear_lista_python(n)
crear_array_numpy(n)
# Out:
# Función 'crear_lista_python' tardó: 0.440216 s
# Función 'crear_array_numpy' tardó: 0.014489 s
# array([      0,       1,       2, ..., 9999997, 9999998, 9999999],
#       shape=(10000000,))

# %%
import numpy as np
n = 10_000_000

# %%
# %%timeit
[i for i in range(n)]
# Out:
# 523 ms ± 3.72 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
lista = [i for i in range(n)]
# Out:
# 402 ms ± 5.67 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
lista = []
for i in range(n):
    lista.append(i)
